-- %% [markdown]
-- # [dbo].[Cart]

-- %%
USE [CuaHangTienLoi]
GO

-- %%
/****** Object:  Table [dbo].[Cart]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cart](
	[idUser] [varchar](15) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[idUser] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[cart_item]

-- %%
/****** Object:  Table [dbo].[cart_item]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cart_item](
	[item_id] [nvarchar](255) NOT NULL,
	[cart_id] [varchar](15) NULL,
	[item_name] [nvarchar](255) NULL,
	[item_price] [int] NULL,
	[quantity] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[item_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KhachHang]

-- %%
/****** Object:  Table [dbo].[KhachHang]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KhachHang](
	[numberPhone] [varchar](15) NOT NULL,
	[Email] [varchar](50) NOT NULL,
	[name] [nvarchar](50) NOT NULL,
	[address] [nvarchar](200) NOT NULL,
	[password] [nvarchar](20) NOT NULL,
	[DiemTichLuy] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[numberPhone] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MyVoucher]

-- %%
/****** Object:  Table [dbo].[MyVoucher]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MyVoucher](
	[numberPhone] [varchar](15) NOT NULL,
	[MaVoucher] [int] NOT NULL,
	[SoLuong] [int] NULL,
 CONSTRAINT [PK_MyVoucher] PRIMARY KEY CLUSTERED 
(
	[numberPhone] ASC,
	[MaVoucher] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NhanVien]

-- %%
/****** Object:  Table [dbo].[NhanVien]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NhanVien](
	[numberPhone] [varchar](15) NOT NULL,
	[Email] [varchar](50) NOT NULL,
	[name] [nvarchar](50) NOT NULL,
	[address] [nvarchar](200) NOT NULL,
	[password] [nvarchar](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[numberPhone] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderHistory]

-- %%
/****** Object:  Table [dbo].[OrderHistory]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderHistory](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[idUser] [varchar](15) NULL,
	[price] [int] NULL,
	[amount] [int] NULL,
	[paymethod] [nvarchar](20) NULL,
	[paydate] [date] NULL,
	[status] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[idProduct] [int] IDENTITY(1,1) NOT NULL,
	[nameProduct] [nvarchar](100) NOT NULL,
	[amountProduct] [int] NOT NULL,
	[priceProduct] [int] NOT NULL,
	[imageProduct] [nvarchar](300) NOT NULL,
	[typeProduct] [varchar](10) NOT NULL,
	[shipment] [varchar](20) NOT NULL,
	[shelflife] [date] NOT NULL,
	[nameSupplier] [nvarchar](255) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[idProduct] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Supplier]

-- %%
/****** Object:  Table [dbo].[Supplier]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Supplier](
	[idSupplier] [int] IDENTITY(1,1) NOT NULL,
	[nameSupplier] [nvarchar](255) NOT NULL,
	[numberphone] [varchar](30) NOT NULL,
	[address] [nvarchar](255) NOT NULL,
	[numberOfTransaction] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[idSupplier] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Voucher]

-- %%
/****** Object:  Table [dbo].[Voucher]    Script Date: 5/14/2023 10:52:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Voucher](
	[MaVoucher] [int] IDENTITY(1,1) NOT NULL,
	[TenVoucher] [nvarchar](100) NOT NULL,
	[GiaVoucher] [int] NOT NULL,
	[HinhAnh] [varchar](300) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[MaVoucher] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__KhachHang__DiemT__267ABA7A]

-- %%
ALTER TABLE [dbo].[KhachHang] ADD  DEFAULT ((0)) FOR [DiemTichLuy]
GO

-- %% [markdown]
-- # [DF__MyVoucher__SoLuo__35BCFE0A]

-- %%
ALTER TABLE [dbo].[MyVoucher] ADD  DEFAULT ((1)) FOR [SoLuong]
GO

-- %% [markdown]
-- # [DF__Supplier__number__29572725]

-- %%
ALTER TABLE [dbo].[Supplier] ADD  DEFAULT ((0)) FOR [numberOfTransaction]
GO

-- %% [markdown]
-- # [FK__Cart__idUser__2E1BDC42]

-- %%
ALTER TABLE [dbo].[Cart]  WITH CHECK ADD FOREIGN KEY([idUser])
REFERENCES [dbo].[NhanVien] ([numberPhone])
GO

-- %% [markdown]
-- # [FK__cart_item__cart___30F848ED]

-- %%
ALTER TABLE [dbo].[cart_item]  WITH CHECK ADD FOREIGN KEY([cart_id])
REFERENCES [dbo].[Cart] ([idUser])
GO

-- %% [markdown]
-- # [FK_MyVoucher_KhachHang]

-- %%
ALTER TABLE [dbo].[MyVoucher]  WITH CHECK ADD  CONSTRAINT [FK_MyVoucher_KhachHang] FOREIGN KEY([numberPhone])
REFERENCES [dbo].[KhachHang] ([numberPhone])
GO
ALTER TABLE [dbo].[MyVoucher] CHECK CONSTRAINT [FK_MyVoucher_KhachHang]
GO

-- %% [markdown]
-- # [FK_MyVoucher_Voucher]

-- %%
ALTER TABLE [dbo].[MyVoucher]  WITH CHECK ADD  CONSTRAINT [FK_MyVoucher_Voucher] FOREIGN KEY([MaVoucher])
REFERENCES [dbo].[Voucher] ([MaVoucher])
GO
ALTER TABLE [dbo].[MyVoucher] CHECK CONSTRAINT [FK_MyVoucher_Voucher]
GO

-- %% [markdown]
-- # [FK__OrderHist__idUse__3A81B327]

-- %%
ALTER TABLE [dbo].[OrderHistory]  WITH CHECK ADD FOREIGN KEY([idUser])
REFERENCES [dbo].[NhanVien] ([numberPhone])
GO
